# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("4G - Sheet1.csv")

# %%
#df.Width.replace({320:1, 384:2,640:3,736:4,1280:5,1920:6}, inplace=True)

# %%
df.columns
# Out:
# Index(['intExpID', 'Column', 'Type', 'total_users', 'intSeg', 'intArr',
#        'intDel', 'intSta', 'intRep', 'intDelRate', 'intActRate', 'intByteSize',
#        'floatBuf', 'algorithm_used', 'Seg_Dur', 'Codec', 'Width', 'Height',
#        'Resolutions', 'FPS', 'Play_Pos', 'RTT', 'Protocol', 'P1203', 'Clae',
#        'Duanmu', 'Yin', 'Yu', 'intUser', 'port', 'rtt_qos', 'tp_qos', 'p_qos'],
#       dtype='object')

# %%
#df.columns

# %%
df['Column'].unique()
# Out:
# array([2, 3, 9, 4, 1, 5, 6, 7, 8])

# %%
df_1 =df[(df['intUser']==2) & (df['total_users']==2) & (df['Column']==1)]

# %%
df_9 =df[(df['intUser']==2)& (df['total_users']==2) & (df['Column']==9)]

# %%
df_8 =df[(df['intUser']==2)& (df['total_users']==2) & (df['Column']==8)]

# %%
df_1.shape[0]
# Out:
# 420

# %%
col_1_df_1 = df_1[(df_1['algorithm_used']=='elastic')]
col_2_df_1 = df_1[(df_1['algorithm_used']=='arbiter')]
col_3_df_1 = df_1[(df_1['algorithm_used']=='average')]
col_4_df_1 = df_1[(df_1['algorithm_used']=='exponential')]
col_5_df_1 = df_1[(df_1['algorithm_used']=='conventional')]
col_6_df_1 = df_1[(df_1['algorithm_used']=='bba')]
col_7_df_1 = df_1[(df_1['algorithm_used']=='logistic')]

# %%
col_1_df_9 = df_9[(df_9['algorithm_used']=='elastic')]
col_2_df_9 = df_9[(df_9['algorithm_used']=='arbiter')]
col_3_df_9 = df_9[(df_9['algorithm_used']=='average')]
col_4_df_9 = df_9[(df_9['algorithm_used']=='exponential')]
col_5_df_9 = df_9[(df_9['algorithm_used']=='conventional')]
col_6_df_9 = df_9[(df_9['algorithm_used']=='bba')]
col_7_df_9 = df_9[(df_9['algorithm_used']=='logistic')]

# %%
col_1_df_8 = df_8[(df_8['algorithm_used']=='elastic')]
col_2_df_8 = df_8[(df_8['algorithm_used']=='arbiter')]
col_3_df_8 = df_8[(df_8['algorithm_used']=='average')]
col_4_df_8 = df_8[(df_8['algorithm_used']=='exponential')]
col_5_df_8 = df_8[(df_8['algorithm_used']=='conventional')]
col_6_df_8 = df_8[(df_8['algorithm_used']=='bba')]
col_7_df_8 = df_8[(df_8['algorithm_used']=='logistic')]

# %%
fig, axs = plt.subplots(4,2,constrained_layout=True,figsize=(9,5))
(ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8) = axs
fig.suptitle('Rate based: Exponential & Conventional [Low - Medium - High] Mbps')
#plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = True
#plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

l1,=ax1.plot(col_4_df_1['intSeg'], col_4_df_1['intActRate'],linestyle=':')
l2,=ax1.plot(col_4_df_9['intSeg'], col_4_df_9['intActRate'],linestyle='--')
l3,= ax1.plot(col_4_df_8['intSeg'], col_4_df_8['intActRate'],linestyle='-.')


#P.1203 of above
ax3.plot(col_4_df_1['intSeg'], col_4_df_1['P1203'],linestyle=':')
ax3.plot(col_4_df_9['intSeg'], col_4_df_9['P1203'],linestyle='--')
ax3.plot(col_4_df_8['intSeg'], col_4_df_8['P1203'],linestyle='-.')

ax5.plot(col_6_df_1['intSeg'], col_6_df_1['rtt_qos'],linestyle=':')
ax5.plot(col_6_df_9['intSeg'], col_6_df_9['rtt_qos'],linestyle='--')
ax5.plot(col_6_df_8['intSeg'], col_6_df_8['rtt_qos'],linestyle='-.')

ax7.plot(col_6_df_1['intSeg'], col_6_df_1['intSta'],linestyle=':')
ax7.plot(col_6_df_9['intSeg'], col_6_df_9['intSta'],linestyle='--')
ax7.plot(col_6_df_8['intSeg'], col_6_df_8['intSta'],linestyle='-.')



ax2.plot(col_5_df_1['intSeg'], col_5_df_1['intActRate'],linestyle=':')
ax2.plot(col_5_df_9['intSeg'], col_5_df_9['intActRate'],linestyle='--')
ax2.plot(col_5_df_8['intSeg'], col_5_df_8['intActRate'],linestyle='-.')

#P.1203 of above
ax4.plot(col_5_df_1['intSeg'], col_5_df_1['P1203'],linestyle=':')
ax4.plot(col_5_df_9['intSeg'], col_5_df_9['P1203'],linestyle='--')
ax4.plot(col_5_df_8['intSeg'], col_5_df_8['P1203'],linestyle='-.')

ax6.plot(col_7_df_1['intSeg'], col_7_df_1['rtt_qos'],linestyle=':')
ax6.plot(col_7_df_9['intSeg'], col_7_df_9['rtt_qos'],linestyle='--')
ax6.plot(col_7_df_8['intSeg'], col_7_df_8['rtt_qos'],linestyle='-.')

ax8.plot(col_7_df_1['intSeg'], col_7_df_1['intSta'],linestyle=':')
ax8.plot(col_7_df_9['intSeg'], col_7_df_9['intSta'],linestyle='--')
ax8.plot(col_7_df_8['intSeg'], col_7_df_8['intSta'],linestyle='-.')



#plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
#for ax in axs.flat:
    #ax.label_outer()
    
for ax in axs.flat:
       ax.label_outer()

#plt.savefig('STATIC/rate_cases.png', format='png')

ax7.set(ylabel='Stall (ms)')
ax5.set(ylabel='RTT')
ax3.set(ylabel='P.1203')
ax1.set(ylabel='Bitrate')
# Out:
# [Text(0, 0.5, 'Bitrate')]
