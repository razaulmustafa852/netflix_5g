# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("4G - Sheet1.csv")

# %%
df.columns
# Out:
# Index(['intExpID', 'Column', 'Type', 'total_users', 'intSeg', 'intArr',
#        'intDel', 'intSta', 'intRep', 'intDelRate', 'intActRate', 'intByteSize',
#        'floatBuf', 'algorithm_used', 'Seg_Dur', 'Codec', 'Width', 'Height',
#        'Resolutions', 'FPS', 'Play_Pos', 'RTT', 'Protocol', 'P1203', 'Clae',
#        'Duanmu', 'Yin', 'Yu', 'intUser', 'port', 'rtt_qos', 'tp_qos', 'p_qos'],
#       dtype='object')

# %%
#df.columns

# %%
df['Column'].unique()
# Out:
# array([2, 3, 9, 4, 1, 5, 6, 7, 8])

# %%
df_1 =df[(df['intUser']==1) & (df['total_users']==2) & (df['Column']==1)]

# %%
df_9 =df[(df['intUser']==1)& (df['total_users']==2) & (df['Column']==9)]

# %%
df_8 =df[(df['intUser']==1)& (df['total_users']==2) & (df['Column']==8)]

# %%
#algo_name = df['algorithm_used'].unique()

# %%
#figname = algo_name[0]#

# %%
df_1.shape[0]
# Out:
# 420

# %%
col_1_df_1 = df_1[(df_1['algorithm_used']=='elastic')]
col_2_df_1 = df_1[(df_1['algorithm_used']=='arbiter')]
col_3_df_1 = df_1[(df_1['algorithm_used']=='average')]
col_4_df_1 = df_1[(df_1['algorithm_used']=='exponential')]
col_5_df_1 = df_1[(df_1['algorithm_used']=='conventional')]
col_6_df_1 = df_1[(df_1['algorithm_used']=='bba')]
col_7_df_1 = df_1[(df_1['algorithm_used']=='logistic')]

# %%
col_1_df_9 = df_9[(df_9['algorithm_used']=='elastic')]
col_2_df_9 = df_9[(df_9['algorithm_used']=='arbiter')]
col_3_df_9 = df_9[(df_9['algorithm_used']=='average')]
col_4_df_9 = df_9[(df_9['algorithm_used']=='exponential')]
col_5_df_9 = df_9[(df_9['algorithm_used']=='conventional')]
col_6_df_9 = df_9[(df_9['algorithm_used']=='bba')]
col_7_df_9 = df_9[(df_9['algorithm_used']=='logistic')]

# %%
col_1_df_8 = df_8[(df_8['algorithm_used']=='elastic')]
col_2_df_8 = df_8[(df_8['algorithm_used']=='arbiter')]
col_3_df_8 = df_8[(df_8['algorithm_used']=='average')]
col_4_df_8 = df_8[(df_8['algorithm_used']=='exponential')]
col_5_df_8 = df_8[(df_8['algorithm_used']=='conventional')]
col_6_df_8 = df_8[(df_8['algorithm_used']=='bba')]
col_7_df_8 = df_8[(df_8['algorithm_used']=='logistic')]

# %%
col_1_df_8.shape[0]
# Out:
# 60

# %%
fig, axs = plt.subplots(3,2,constrained_layout=True,figsize=(9,4.5))
(ax1, ax2), (ax3, ax4), (ax5, ax6) = axs
fig.suptitle('Buffered: BBA-2 & Logistic [Low - Medium - High] Mbps')

l1,= ax1.plot(col_6_df_1['intSeg'], col_6_df_1['Resolutions'],linestyle=':')
l2,= ax1.plot(col_6_df_9['intSeg'], col_6_df_9['Resolutions'],linestyle='--')
l3,= ax1.plot(col_6_df_8['intSeg'], col_6_df_8['Resolutions'],linestyle='-.')


#P.1203 of above
ax3.plot(col_6_df_1['intSeg'], col_6_df_1['P1203'],linestyle=':')
ax3.plot(col_6_df_9['intSeg'], col_6_df_9['P1203'],linestyle='--')
ax3.plot(col_6_df_8['intSeg'], col_6_df_8['P1203'],linestyle='-.')

ax5.plot(col_6_df_1['intSeg'], col_6_df_1['rtt_qos'],linestyle=':')
ax5.plot(col_6_df_9['intSeg'], col_6_df_9['rtt_qos'],linestyle='--')
ax5.plot(col_6_df_8['intSeg'], col_6_df_8['rtt_qos'],linestyle='-.')







ax2.plot(col_7_df_1['intSeg'], col_7_df_1['Resolutions'],linestyle=':')
ax2.plot(col_7_df_9['intSeg'], col_7_df_9['Resolutions'],linestyle='--')
ax2.plot(col_7_df_8['intSeg'], col_7_df_8['Resolutions'],linestyle='-.')

#P.1203 of above
ax4.plot(col_7_df_1['intSeg'], col_7_df_1['P1203'],linestyle=':')
ax4.plot(col_7_df_9['intSeg'], col_7_df_9['P1203'],linestyle='--')
ax4.plot(col_7_df_8['intSeg'], col_7_df_8['P1203'],linestyle='-.')

ax6.plot(col_7_df_1['intSeg'], col_7_df_1['rtt_qos'],linestyle=':')
ax6.plot(col_7_df_9['intSeg'], col_7_df_9['rtt_qos'],linestyle='--')
ax6.plot(col_7_df_8['intSeg'], col_7_df_8['rtt_qos'],linestyle='-.')



plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
for ax in axs.flat:
    ax.label_outer()

plt.savefig('STATIC/buffered_cases_rtt.png', format='png')

# %%
#fig, ax = plt.subplots()
#ax.plot(col_1['intSeg'], col_1['Resolutions'],linestyle='-.')
#ax.plot(col_1['intSeg'], col_2['Resolutions'],linestyle='-.')

# %%
fig, axs = plt.subplots(3,2,constrained_layout=True,figsize=(9,4.5))
(ax1, ax2), (ax3, ax4) , (ax5, ax6)= axs
fig.suptitle('Rate based: Elastic & Arbiter [Low - Medium - High] Mbps')

l1,= ax1.plot(col_1_df_1['intSeg'], col_1_df_1['Resolutions'],linestyle=':')
l2,= ax1.plot(col_1_df_9['intSeg'], col_1_df_9['Resolutions'],linestyle='--')
l3,= ax1.plot(col_1_df_8['intSeg'], col_1_df_8['Resolutions'],linestyle='-.')


#P.1203 of above
ax3.plot(col_1_df_1['intSeg'], col_1_df_1['P1203'],linestyle=':')
ax3.plot(col_1_df_9['intSeg'], col_1_df_9['P1203'],linestyle='--')
ax3.plot(col_1_df_8['intSeg'], col_1_df_8['P1203'],linestyle='-.')

ax5.plot(col_1_df_1['intSeg'], col_1_df_1['rtt_qos'],linestyle=':')
ax5.plot(col_1_df_9['intSeg'], col_1_df_9['rtt_qos'],linestyle='--')
ax5.plot(col_1_df_8['intSeg'], col_1_df_8['rtt_qos'],linestyle='-.')




ax2.plot(col_2_df_1['intSeg'], col_2_df_1['Resolutions'],linestyle=':')
ax2.plot(col_2_df_9['intSeg'], col_2_df_9['Resolutions'],linestyle='--')
ax2.plot(col_2_df_8['intSeg'], col_2_df_8['Resolutions'],linestyle='-.')

#P.1203 of above
ax4.plot(col_2_df_1['intSeg'], col_2_df_1['P1203'],linestyle=':')
ax4.plot(col_2_df_9['intSeg'], col_2_df_9['P1203'],linestyle='--')
ax4.plot(col_2_df_8['intSeg'], col_2_df_8['P1203'],linestyle='-.')


ax6.plot(col_2_df_1['intSeg'], col_2_df_1['rtt_qos'],linestyle=':')
ax6.plot(col_2_df_9['intSeg'], col_2_df_9['rtt_qos'],linestyle='--')
ax6.plot(col_2_df_8['intSeg'], col_2_df_8['rtt_qos'],linestyle='-.')




plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
for ax in axs.flat:
    ax.label_outer()

plt.savefig('STATIC/hybrid_cases_rtt.png', format='png')
